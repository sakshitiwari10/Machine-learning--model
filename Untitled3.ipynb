# %%
# !pip install --upgrade numpy pyarrow
# Out:
# Requirement already satisfied: numpy in c:\users\skt20\anaconda3\lib\site-packages (2.4.2)
# Collecting numpy
#   Downloading numpy-2.5.0-cp312-cp312-win_amd64.whl.metadata (6.6 kB)
# Requirement already satisfied: pyarrow in c:\users\skt20\anaconda3\lib\site-packages (16.1.0)
# Collecting pyarrow
#   Downloading pyarrow-24.0.0-cp312-cp312-win_amd64.whl.metadata (3.0 kB)
# Downloading numpy-2.5.0-cp312-cp312-win_amd64.whl (12.4 MB)
#    ---------------------------------------- 0.0/12.4 MB ? eta -:--:--
#    ---------- ----------------------------- 3.4/12.4 MB 20.0 MB/s eta 0:00:01
#    ----------------------- ---------------- 7.3/12.4 MB 19.7 MB/s eta 0:00:01
#    ------------------------------------- -- 11.5/12.4 MB 19.5 MB/s eta 0:00:01
#    ---------------------------------------  12.3/12.4 MB 19.3 MB/s eta 0:00:01
#    ---------------------------------------- 12.4/12.4 MB 14.7 MB/s eta 0:00:00
# Downloading pyarrow-24.0.0-cp312-cp312-win_amd64.whl (27.4 MB)
#    ---------------------------------------- 0.0/27.4 MB ? eta -:--:--
#    ----- ---------------------------------- 3.7/27.4 MB 18.1 MB/s eta 0:00:02
#    --------- ------------------------------ 6.8/27.4 MB 16.1 MB/s eta 0:00:02
#    --------------- ------------------------ 10.5/27.4 MB 16.8 MB/s eta 0:00:02
#    ----------------- ---------------------- 12.1/27.4 MB 16.8 MB/s eta 0:00:01
#    ----------------- ---------------------- 12.1/27.4 MB 16.8 MB/s eta 0:00:01
#    --------------------- ------------------ 14.7/27.4 MB 11.7 MB/s eta 0:00:02
#    ------------------------ --------------- 17.0/27.4 MB 11.8 MB/s eta 0:00:01
#    ----------------------------- ---------- 20.4/27.4 MB 12.1 MB/s eta 0:00:01
#    ---------------------------------- ----- 23.6/27.4 MB 12.4 MB/s eta 0:00:01
#    ------------------------------------- -- 25.7/27.4 MB 12.6 MB/s eta 0:00:01
#    ------------------------------------- -- 25.7/27.4 MB 12.6 MB/s eta 0:00:01
#    ---------------------------------------  27.3/27.4 MB 11.1 MB/s eta 0:00:01
#    ---------------------------------------  27.3/27.4 MB 11.1 MB/s eta 0:00:01
#    ---------------------------------------- 27.4/27.4 MB 9.6 MB/s eta 0:00:00
# Installing collected packages: pyarrow, numpy
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 16.1.0
#     Uninstalling pyarrow-16.1.0:
#       Successfully uninstalled pyarrow-16.1.0
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.4.2
#     Uninstalling numpy-2.4.2:
#       Successfully uninstalled numpy-2.4.2
# Successfully installed numpy-2.5.0 pyarrow-24.0.0
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x00000129F2A92F90>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/numpy/
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\skt20\anaconda3\Lib\site-packages\~umpy.libs'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\skt20\anaconda3\Lib\site-packages\~umpy'.
#   You can safely remove it manually.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gensim 4.3.3 requires numpy<2.0,>=1.18.5, but you have numpy 2.5.0 which is incompatible.
# gensim 4.3.3 requires scipy<1.14.0,>=1.7.0, but you have scipy 1.17.0 which is incompatible.
# numba 0.60.0 requires numpy<2.1,>=1.22, but you have numpy 2.5.0 which is incompatible.
# streamlit 1.37.1 requires pandas<3,>=1.3.0, but you have pandas 3.0.0 which is incompatible.
# streamlit 1.37.1 requires protobuf<6,>=3.20, but you have protobuf 7.35.1 which is incompatible.

# %%
import os
os.kill(os.getpid(), 9)

# %%
import numpy as np
from sklearn.model_selection import train_test_split

# %%
y=np.array([0]* 90+[1]*10)

# %%
y_train, y_test = train_test_split(y, test_size=0.2, random_state=42)

# %%
print("without stratification")
print(" Train failure percentage :", round ( y_train . mean () * 100 , 2) , "%")
print (" Test failure percentage :", round ( y_test . mean () * 100 , 2) , "%")
# Out:
# without stratification
#  Train failure percentage : 11.25 %
#  Test failure percentage : 5.0 %
